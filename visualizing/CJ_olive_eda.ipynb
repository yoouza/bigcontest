# %% [markdown]
# <a href="https://colab.research.google.com/github/yoouza/bigcontest/blob/master/visualizing/%EB%AC%BC%EB%A5%98%EB%A5%BC%ED%99%95%EC%9D%B8%ED%95%B4%EB%B3%B4%EC%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 

df = pd.read_excel('/content/CJ Olive/2020 빅콘테스트_CJ올리브네트웍스_제공DB.xlsx', encoding='utf-8')
df.head()
# Out:
#    DL_YMD DL_GD_LCLS_NM  DL_GD_LCLS_CD  ... HDNG_NM  HDNG_CD INVC_CONT
# 0  190201         도서/음반             12  ...     동화동      665        16
# 1  190201       가구/인테리어             10  ...     신당동      615         4
# 2  190201       가구/인테리어             10  ...    성내1동      565         1
# 3  190201         도서/음반             12  ...    남산2동      650         6
# 4  190201        디지털/가전             13  ...    고산3동      690        21
#
# [5 rows x 10 columns]

# %%
gb_df = df.groupby(['DL_YMD', 'DL_GD_LCLS_NM'])['INVC_CONT'].sum()
gb_df = pd.DataFrame(gb_df)
gb_df = gb_df.reset_index()
gb_df.head()
# Out:
#    DL_YMD DL_GD_LCLS_NM  INVC_CONT
# 0  190201       가구/인테리어        262
# 1  190201         도서/음반       2434
# 2  190201        디지털/가전        935
# 3  190201          생활건강       1483
# 4  190201        스포츠/레저         53

# %%
column_nm = list(df['DL_GD_LCLS_NM'].unique())
column_e = ['library', 'interior', 'digital', 'sports', 'jewerly', 'food', 'life&health', 'clothes', 'cosmetic', 'baby']
column_nm
# Out:
# ['도서/음반',
#  '가구/인테리어',
#  '디지털/가전',
#  '스포츠/레저',
#  '패션잡화',
#  '식품',
#  '생활건강',
#  '패션의류',
#  '화장품/미용',
#  '출산/육아']

# %%
import datetime

dates = list(df['DL_YMD'].unique())
time = []
time1 = []
time2 = []
time3 = []
# 날짜 데이터로 저장
for date in dates:
    time.append(date)
    time3.append(datetime.datetime.strptime('20'+date.astype('str'), "%Y%m%d").date())
    if int(date) < 200000:
        time1.append(datetime.datetime.strptime('20'+date.astype('str'), "%Y%m%d").date())
    else:
        time2.append(datetime.datetime.strptime('20'+date.astype('str'), "%Y%m%d").date())

time1[0:5]
# Out:
# [datetime.date(2019, 2, 1),
#  datetime.date(2019, 2, 2),
#  datetime.date(2019, 2, 3),
#  datetime.date(2019, 2, 4),
#  datetime.date(2019, 2, 5)]

# %%
# 주말 제외 날짜 정리
time1_WD = []
for i in time1:
    if i.month == 2:
        if i.day % 7 != 2 and i.day % 7 != 3 and i.day != 5: # 설날 당일 제외
            time1_WD.append(i)
    if i.month == 3:
        if i.day % 7 != 2 and i.day % 7 != 3 and i.day != 1: # 3.1절 제외
            time1_WD.append(i)
    if i.month == 4:
        if i.day % 7 != 6 and i.day % 7 != 0:
            time1_WD.append(i)
    if i.month == 5:
        if i.day % 7 != 4 and i.day % 7 != 5 and i.day != 6 and i.day != 1: # 어린이날 대체 휴일, 근로자의 날 제외
            time1_WD.append(i)

time2_WD = []
for i in time2:
    if i.month == 2:
        if i.day % 7 != 1 and i.day % 7 != 2:
            time2_WD.append(i)
    if i.month == 3:
        if i.day % 7 != 0 and i.day % 7 != 1 and i.day != 1: # 3.1절 제외
            time2_WD.append(i)
    if i.month == 4:
        if i.day % 7 != 4 and i.day % 7 != 5 and i.day != 15 and i.day != 30: # 선거일, 부처님 오신날 제외
            time2_WD.append(i)
    if i.month == 5:
        if i.day % 7 != 2 and i.day % 7 != 3 and i.day != 5: # 어린이날 제외
            time2_WD.append(i)            

time1_WD[:5], time2_WD[:5]
# Out:
# ([datetime.date(2019, 2, 1),
#   datetime.date(2019, 2, 4),
#   datetime.date(2019, 2, 6),
#   datetime.date(2019, 2, 7),
#   datetime.date(2019, 2, 8)],
#  [datetime.date(2020, 2, 3),
#   datetime.date(2020, 2, 4),
#   datetime.date(2020, 2, 5),
#   datetime.date(2020, 2, 6),
#   datetime.date(2020, 2, 7)])

# %%
d = []
columns = []

for column in column_nm:
    e = pd.DataFrame(gb_df[gb_df['DL_GD_LCLS_NM'] == column])
    columns.append(column)
    tmp = []
    for t in time:
        try: 
            tmp.append(int(e[e['DL_YMD'] == t]['INVC_CONT'].values))
        except:
            tmp.append(0)
    d.append(tmp)

len(d)
# Out:
# 10

# %%
import numpy as np

df1 = pd.DataFrame(np.array(d), index=column_e, columns=time3)

df_2019 = df1[time1_WD]
df_2020 = df1[time2_WD]

df_2019, df_2020
# Out:
# (             2019-02-01  2019-02-04  ...  2019-05-30  2019-05-31
#  library            2434           1  ...        4013        3316
#  interior            262           9  ...        2639        2452
#  digital             935           3  ...        5411        5056
#  sports               53           0  ...         905         776
#  jewerly             897           3  ...        5963        5194
#  food               1336          12  ...       16796       14969
#  life&health        1483          80  ...       12153       11070
#  clothes            2618           5  ...       17776       15924
#  cosmetic           1519           9  ...        8495        7756
#  baby                 38           1  ...         427         386
#
#  [10 rows x 82 columns],
#               2020-02-03  2020-02-04  ...  2020-05-28  2020-05-29
#  library            8468        6275  ...        6656        6155
#  interior           5168        3183  ...        3859        3189
#  digital           12720        7527  ...        8094        6827
#  sports             1545         995  ...        1343        1066
#  jewerly           10135        6629  ...        7161        7224
#  food              36594       25004  ...       22348       19415
#  life&health       36825       22759  ...       19514       17426
#  clothes           27031       16964  ...       21004       21039
#  cosmetic          22462       12720  ...       10403        9110
#  baby                816         475  ...         509         521
#
#  [10 rows x 82 columns])

# %%
idx1 = ['library', 'interior', 'baby', 'sports', 'jewerly']
idx2 = ['food', 'life&health', 'clothes', 'cosmetic', 'digital']
a = pd.DataFrame(df_2019.loc[idx1])
b = pd.DataFrame(df_2019.loc[idx2])
c = pd.DataFrame(df_2020.loc[idx1])
d = pd.DataFrame(df_2020.loc[idx2])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 2019년 도서/음반, 가구/인테리어, 출산/육아, 스포츠/레저, 패션잡화

plt.figure(figsize=(40, 30))

sns.lineplot(data = a.T)
plt.legend(('library', 'interior', 'baby', 'sports', 'jewerly'), fontsize=30)
plt.tick_params(labelsize=20) # 5월 1일이 근로자의 날이라 일을 안 한듯?

# %%
# 2019년 디지털/가전, 식품, 생활건강, 패션의류, 화장품/미용

plt.figure(figsize=(30, 20))

sns.lineplot(data = b.T)
plt.legend(('food', 'life&health', 'clothes', 'cosmetic', 'digital'), fontsize=30)
plt.tick_params(labelsize=20)

# %%
# 2020년 도서/음반, 가구/인테리어, 출산/육아, 스포츠/레저, 패션잡화

plt.figure(figsize=(30, 20))

sns.lineplot(data = c.T)
plt.legend(('library', 'interior', 'baby', 'sports', 'jewerly'), fontsize=30)
plt.tick_params(labelsize=20)

# %%
# 2020년 디지털/가전, 식품, 생활건강, 패션의류, 화장품/미용

plt.figure(figsize=(30, 20))

sns.lineplot(data = d.T)
plt.legend(('food', 'life&health', 'clothes', 'cosmetic', 'digital'), fontsize=30)
plt.tick_params(labelsize=20)

# %%
# 동일 날짜를 비교
len(df_2019.T), len(df_2020.T)
# Out:
# (82, 82)

# %%
# 전년도와 비교
diff = np.array(df_2020) - np.array(df_2019)
diff = pd.DataFrame(diff, index=column_e, columns = time2_WD)
diff
# Out:
#              2020-02-03  2020-02-04  ...  2020-05-28  2020-05-29
# library            6034        6274  ...        2643        2839
# interior           4906        3174  ...        1220         737
# digital           11785        7524  ...        2683        1771
# sports             1492         995  ...         438         290
# jewerly            9238        6626  ...        1198        2030
# food              35258       24992  ...        5552        4446
# life&health       35342       22679  ...        7361        6356
# clothes           24413       16959  ...        3228        5115
# cosmetic          20943       12711  ...        1908        1354
# baby                778         474  ...          82         135
#
# [10 rows x 82 columns]

# %%
idx1 = ['library', 'interior', 'baby', 'sports', 'jewerly']
idx2 = ['food', 'life&health', 'clothes', 'cosmetic', 'digital']
diff_a = pd.DataFrame(diff.loc[idx1])
diff_b = pd.DataFrame(diff.loc[idx2])
diff_a
# Out:
#           2020-02-03  2020-02-04  ...  2020-05-28  2020-05-29
# library         6034        6274  ...        2643        2839
# interior        4906        3174  ...        1220         737
# baby             778         474  ...          82         135
# sports          1492         995  ...         438         290
# jewerly         9238        6626  ...        1198        2030
#
# [5 rows x 82 columns]

# %%
# 2019년 대비 2020년의 도서/음반, 가구/인테리어, 출산/육아, 스포츠/레저, 패션잡화 주문량

plt.figure(figsize=(30, 20))

sns.lineplot(data = diff_a.T)
plt.legend(('library', 'interior', 'baby', 'sports', 'jewerly'), fontsize=30)
plt.tick_params(labelsize=20)

# %%
# 2019년 대비 2020년의 디지털/가전, 식품, 생활건강, 패션의류, 화장품/미용 주문량

plt.figure(figsize=(30, 20))

sns.lineplot(data = diff_b.T)
plt.legend(('food', 'life&health', 'clothes', 'cosmetic', 'digital'), fontsize=30)
plt.tick_params(labelsize=20)
